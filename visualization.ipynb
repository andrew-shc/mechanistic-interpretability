# %%
from matplotlib import pyplot as plt

# %%
plt.plot([0.047530998924264205,
        0.03307715989649296,
        0.02655665897246864,
        0.023808059593041737,
        0.02253271594505619,
        0.0218720159113959,
        0.021513539228450368,
        0.02130996625594519,
        0.0211871347769543,
        0.021115009948887205,
])
plt.xlabel("Epochs")
plt.ylabel("Loss")
# Out:
# Text(0.5, 0, 'Epochs')
